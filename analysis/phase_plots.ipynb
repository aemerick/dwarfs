# %%
# %matplotlib inline 

import yt
import cgs as cgs
import matplotlib.pyplot as plt
import numpy as np
# Out:
# using cgs py

# %%
number = 20
ds = yt.load('./../flash_runs/leo_T/SN_LT_n150_v4_nh4/0000_cfloor_global_5pc/dwarf_fullp_hdf5_plt_cnt_%0004i'%(number))

# %%
reg = ds.sphere((2.0,5.0,5.0)*yt.units.kpc,(0.5,'kpc'))


plot = yt.PhasePlot(reg, 'density', 'temperature', ['cell_mass'], weight_field = None)

# %%
plot.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
